# %%
# -*- coding: utf-8 -*-
import torch
import torchvision
import torchvision.transforms as transforms

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
         #(0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64,
                                         shuffle=False, num_workers=2)

#classes = ('plane', 'car', 'bird', 'cat',
#           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
#   0%|          | 0/169001437 [00:00<?, ?it/s]
# ...
# 169009152it [00:06, 27951704.17it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
#print(' '.join('%5s' % classes[labels[j]] for j in range(4)))(0.5, 0.5, 0.5), (0.5, 0.5, 0.5)(0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %%
'''VGG11/13/16/19 in Pytorch.'''
import torch
import torch.nn as nn


cfg = {
    'VGG11': [32, 32, 'M', 'D2', 64, 64, 'M', 'D3', 128, 128, 'M', 'D4'],
    'VGG13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}


class VGG(nn.Module):
    def __init__(self, vgg_name):
        super(VGG, self).__init__()
        self.features = self._make_layers(cfg[vgg_name])
        self.classifier = nn.Linear(2048, 10)

    def forward(self, x):
        out = self.features(x)
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out

    def _make_layers(self, cfg):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            elif x == 'D2':
                layers += [nn.Dropout(p=0.2)]
            elif x == 'D3':
                layers += [nn.Dropout(p=0.3)]
            elif x == 'D4':
                layers += [nn.Dropout(p=0.4)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.ReLU(inplace=True),
                           nn.BatchNorm2d(x)]
                in_channels = x
        #layers += [nn.AvgPool2d(kernel_size=1, stride=1)]
        return nn.Sequential(*layers)


def test():
    net = VGG('VGG11')
    x = torch.randn(2,3,32,32)
    y = net(x)
    print(y.size())

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
net = VGG('VGG11').to(device)

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.00001, momentum=0.9, weight_decay=5e-4)

# %%
for epoch in range(5):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device), data[1].to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
    print('[%d, %5d] loss: %.3f' %
          (epoch + 1, i + 1, running_loss / 2000))
    running_loss = 0.0

print('Finished Training')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-22ba36251b37> in <module>
#      12         outputs = net(inputs)
#      13         loss = criterion(outputs, labels)
# ---> 14         loss.backward()
#      15         optimizer.step()
#      16
#
# ~/.local/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# ~/.local/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ...

# %%
PATH = './cifar_net1.pth'
# torch.save(net.state_dict(), PATH)

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(64)))

# %%
net = VGG('VGG11').to(device)
net.load_state_dict(torch.load(PATH))

# outputs = net(images.to(device))
# 
# _, predicted = torch.max(outputs, 1)

# print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
#                               for j in range(64)))
# Out:
# <All keys matched successfully>

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))

# %%
net

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = net.features[0]
        self.relu1 = net.features[1]
        self.bn1 = net.features[2]
        
        self.conv2 = net.features[3]
        self.relu2 = net.features[4]
        self.bn2 = net.features[5]
        
        self.mp1 = net.features[6]
        self.dp1 = net.features[7]
        
        self.conv3 = net.features[8]
        self.relu3 = net.features[9]
        self.bn3 = net.features[10]
        
        self.conv4 = net.features[11]
        self.relu4 = net.features[12]
        self.bn4 = net.features[13]
        
        self.mp2 = net.features[14]
        self.dp2 = net.features[15]
        
        self.conv5 = net.features[16]
        self.relu5 = net.features[17]
        self.bn5 = net.features[18]
        
        self.conv6 = net.features[19]
        self.relu6 = net.features[20]
        self.bn6 = net.features[21]
        
    def forward(self, x):
        x = self.bn1(F.relu(self.conv1(x)))
        x = self.bn2(F.relu(self.conv2(x)))
        x = self.mp1(x)
        
        x = self.bn3(F.relu(self.conv3(x)))
        x = self.bn4(F.relu(self.conv4(x)))
        x = self.mp2(x)
        
        x = self.bn5(F.relu(self.conv5(x)))
        x = self.bn6(F.relu(self.conv6(x)))
        return x

net_0 = Net()

# %%
net_0
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu1): ReLU(inplace=True)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU(inplace=True)
#   (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (mp1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dp1): Dropout(p=0.2, inplace=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu3): ReLU(inplace=True)
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu4): ReLU(inplace=True)
#   (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
net
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace=True)
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
w = net.features[0].weight.data

# %%
res = 128
dist_metric = torch.empty((res,res))

w = net.features[19].weight.data

gamma = net.features[21].weight.data
beta = net.features[21].bias.data

for i in range(res):
    for j in range(res):
        prod = np.corrcoef(w[i].flatten().detach().cpu().numpy(), w[j].flatten().detach().cpu().numpy())[0,1]
        g_term = gamma[i].pow(2) + gamma[j].pow(2) - 2*gamma[i]*gamma[j]*prod
        b_term = (beta[i] - beta[j]).pow(2)
        dist_metric[i,j] = g_term + b_term

# %%
net_0(images[0:1,:,:,:]).shape

# %%
res = 128
dist_base = torch.empty((res,res))
with torch.no_grad():
    for data in trainloader:
        images = data[0].to(device)
        outputs = net_0(images)
        for i in range(res):
            for j in range(res):
                dist_base[i,j] = (outputs[:,i,:,:] - outputs[:,j,:,:]).pow(2).sum()
        break

# %%
dist_base = dist_base.detach().cpu().numpy()

# %%
dist_metric = dist_metric.detach().cpu().numpy()

# %%
np.corrcoef(dist_metric.flatten(), dist_base.flatten())
# Out:
# array([[1.        , 0.86883116],
#        [0.86883116, 1.        ]])

# %%
outputs[1:n_samples+1, i, :, :].reshape((n_samples,-1))

# %%
outputs.shape

# %%
out1 = (outputs - outputs.min(dim=3)[0].min(dim=2)[0].reshape((10000,128,1,1)))

# %%
outputs = torch.div(outputs, outputs.max(dim=3)[0].max(dim=2)[0].reshape((10000,128,1,1)))

# %%
import time

# %%
outputs.shape

# %%
from EDGE_4_4_1 import EDGE

# %%
res = 128
mi_mat = torch.zeros((res,res))

n_samples = 9999

for i in range(res):
    s = time.time()
    for j in range(i,res):
        X = outputs[1:n_samples+1, i, :, :].reshape((n_samples,-1)).detach().cpu().numpy()
        Y = outputs[1:n_samples+1, j, :, :].reshape((n_samples,-1)).detach().cpu().numpy()
        
        X = X - X.min()
        X = X / X.max()
        
        Y = Y - Y.min()
        Y = Y / Y.max()
        
        mi_mat[i,j] = EDGE(X, Y, U=20, epsilon=[0.5,0.5], normalize_epsilon=False, L_ensemble=3, hashing='p-stable')

    end = time.time() - s
    print(end)
x = mi_mat.clone()
x = x.t()

for i in range(res):
    x[i,i] = 0
    
x = x + mi_mat
# Out:
# 58.783400774002075
# 57.563640117645264
# 56.77919960021973
# 56.94554543495178
# 56.16057753562927
# 54.59691858291626
# 56.558886766433716
# 56.96286582946777
# 55.71782064437866
# 54.96699500083923
# 56.03775405883789
# 52.53228998184204
# 55.58945059776306
# 52.9344584941864
# 55.976340770721436
# 53.171064138412476
# 51.632078886032104
# 50.88839554786682
# 48.831045389175415
# 48.76737689971924
# 49.247559547424316
# 48.84432339668274
# 48.456116676330566
# 47.89395046234131
# 49.21668577194214
# 48.75890755653381
# 46.629321813583374
# 46.64459776878357
# 46.21209692955017
# 45.82444190979004
# 44.6039252281189
# 43.819360971450806
# 43.4572274684906
# 43.19227313995361
# 43.189292192459106
# 44.12286949157715
# 43.82283902168274
# 42.98123002052307
# 42.61590123176575
# 42.58784580230713
# 41.79245209693909
# 42.15143179893494
# 41.859137535095215
# 40.21346473693848
# 41.8063440322876
# 37.99756217002869
# 38.36378216743469
# 37.19928050041199
# 36.628581523895264
# ...

# %%
for i in range(128):
    x[i,:] = x[i,:]/max(x[i,:])

plt.imshow(x)
plt.colorbar()
plt.show()

# %%
np.corrcoef(x.flatten(), dist_matrix.flatten())
# Out:
# array([[1.        , 0.53663219],
#        [0.53663219, 1.        ]])

# %%
for i in range(64):
    x[i,:] = x[i,:]/max(x[i,:])

plt.imshow(x)
plt.colorbar()
plt.show()

# %%
tempx = x.clone()

# %%
X = outputs[1:n_samples+1, 12, :, :].reshape((n_samples,-1)).detach().cpu().numpy()
Y = outputs[1:n_samples+1, 3, :, :].reshape((n_samples,-1)).detach().cpu().numpy()

# %%
EDGE(Y,X,U=20, epsilon=[1,1])

# %%
ind = 2
x[ind], x[ind].max()

# %%
import matplotlib.pyplot as plt

# %%
for ind in range(32):
    print((x[ind] == x[ind].max())*1)

# %%
mi_temp = x.clone()

# %%
x = mi_temp.clone()

# %%
for i in range(res):
    x[i,:] = x[i,:]/x[i,:].max()
#    dist_matrix[i,:] = dist_metric[i,:]/dist_metric[i,:].max()

# %%
x.max()

# %%
np.corrcoef((x).detach().cpu().numpy().flatten(), (dist_matrix).flatten())

# %%
plt.imshow((x))
plt.colorbar()
plt.show()

# %%
x[30,:]

# %%
torch.save(mi_temp, 'mi_l1.pt')

# %%
mi_l6 = torch.load('mi_l6.pt')

# %%
np.corrcoef(x.cpu().numpy().flatten(), mi_l6.cpu().numpy().flatten())

# %%
temp = outputs[1:100,1,:,:]

# %%
temp.reshape((99, -1)).t()

# %%
torch.cuda.empty_cache()

# %%
delta = 1
dist_matrix = np.exp(- dist_metric ** 2 / (2. * delta ** 2))

# %%
np.corrcoef(dist_base.flatten(), (dist_matrix).flatten())
# Out:
# array([[ 1.       , -0.8530303],
#        [-0.8530303,  1.       ]])

# %%
import sklearn

# %%
from sklearn.cluster import SpectralClustering

# %%
clustering = SpectralClustering(n_clusters=16,affinity="precomputed",assign_labels="discretize",random_state=0).fit(dist_matrix)

# %%
out = (clustering.labels_)

# %%
out

# %%
ind = np.argsort(out)

# %%
dist_matrix[2,3:].max()

# %%
dist_matrix[87,2]

# %%
np.argsort((out == 4)*1)

# %%
dist_matrix[0], dist_matrix[8]

# %%
from scipy import io

# %%
f1 = io.loadmat('f1.mat')
f57 = io.loadmat('f57.mat')
f1 = f1['f1'].transpose()
f57 = f57['f57'].transpose()

# %%
L, ep = 10, 0.2
EDGE(f57, f57, U=20, epsilon=[ep,ep], normalize_epsilon=False, L_ensemble=L, hashing='p-stable'), EDGE(f1, f1, U=20, epsilon=[ep,ep], normalize_epsilon=False, L_ensemble=L, hashing='p-stable'), EDGE(f57, f1, U=20, epsilon=[ep,ep], normalize_epsilon=False, L_ensemble=L, hashing='p-stable'), EDGE(f1, f57, U=20, epsilon=[ep,ep], normalize_epsilon=False, L_ensemble=L, hashing='p-stable')

# %%
#import numpy as np
rdist = np.random.normal(0, 1, (50000, 256))

# %%
#L, ep = 5, 0.1
EDGE(rdist, rdist, U=20, epsilon=[ep,ep], normalize_epsilon=False, L_ensemble=L, hashing='p-stable'), EDGE(f1, f1, U=20, epsilon=[ep,ep], normalize_epsilon=False, L_ensemble=L, hashing='p-stable'), EDGE(rdist, f1, U=20, epsilon=[ep,ep], normalize_epsilon=False, L_ensemble=L, hashing='p-stable'), EDGE(f1, rdist, U=20, epsilon=[ep,ep], normalize_epsilon=False, L_ensemble=L, hashing='p-stable')
